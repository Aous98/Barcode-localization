ss')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend()
plt.grid( linestyle='-', linewidth=1)
plt.show()

# %%
plt.figure(figsize=(10,8))

plt.title('Train and validation accuracy')
plt.xlabel('epoch')
plt.ylabel('Accuracy')
plt.plot(ep, train_acc, label='train acc')
plt.plot(ep, val_acc, label='validation acc')
plt.legend()
plt.grid( linestyle='-', linewidth=1)

plt.show()

# %%
plt.figure(figsize=(10,8))
plt.title('Train and validation IoU')
plt.xlabel('epoch')
plt.ylabel('IoU')
plt.plot(ep, train_iou, label='train')
plt.plot(ep, val_iou, label='validation')

plt.legend()
plt.grid( linestyle='-', linewidth=1)

plt.show()

# %%
import numpy as np
import cv2
import os

count = 0
data_path = "/home/aous/Desktop/MIPT/project/full data resized/predict/mask resized/"
save_path = "/home/aous/Desktop/MIPT/project/full data resized/predict/masks with contours/"
for mask_num in os.listdir(data_path):
    mask = cv2.imread(data_path + mask_num,0)
    contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    vertex_image = mask.copy()
    contours_coordinates = []
    
    for contour in contours:
        epsilon = 0.013 * cv2.arcLength(contour, True)
        approx = cv2.approxPolyDP(contour, epsilon, True)
    
        for point in approx:
            x, y = point[0]
            contours_coordinates.append([y,x])
            cv2.circle(vertex_image, (x, y), 5, 128, -1)
            cv2.imwrite(save_path+mask_num, vertex_image)
    
    # plt.imshow(vertex_image, cmap='gray')
    
    # print(contours_coordinates)
    
    # print(contours)
    if len(contours_coordinates) != 6:
        count += 1
        print(mask_num, len(contours_coordinates))
        # cv2.circle(vertex_image, (x, y), 5, 128, -1)
        # plt.imshow(vertex_image, cmap='gray')
print(count)
# Out:
# 1457.png 4
# 4909.png 7
# 5782.png 4
# 436.png 7
# 331.png 5
# 2463.png 4
# 5127.png 4
# 286.png 4
# 8

# %% [markdown]
# ## Prediction
#
#
# 250 of images for the prediction:

# %%
import os
from PIL import Image
from torch.utils.data.dataset import Dataset
from torchvision import transforms
import torch
import torch.nn as nn 
from torch import optim, nn
from torch.utils.data import DataLoader, random_split
from tqdm import tqdm
import matplotlib.pyplot as plt
import numpy as np
import torchvision.transforms.functional as TF
import copy
import cv2


class DoubleConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.conv_op = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        return self.conv_op(x)


class DownSample(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.conv = DoubleConv(in_channels, out_channels)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)

    def forward(self, x):
        down = self.conv(x)
        p = self.pool(down)

        return down, p


class UpSample(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.up = nn.ConvTranspose2d(in_channels, in_channels//2, kernel_size=2, stride=2)
        self.conv = DoubleConv(in_channels, out_channels)

    def forward(self, x1, x2):
       x1 = self.up(x1)
       x = torch.cat([x1, x2], 1)
       return self.conv(x)


class UNet(nn.Module):
    def __init__(self, in_channels, num_classes):
        super().__init__()
        self.down_convolution_1 = DownSample(in_channels, 64)
        self.down_convolution_2 = DownSample(64, 128)
        self.down_convolution_3 = DownSample(128, 256)
        self.down_convolution_4 = DownSample(256, 512)

        self.bottle_neck = DoubleConv(512, 1024)

        self.up_convolution_1 = UpSample(1024, 512)
        self.up_convolution_2 = UpSample(512, 256)
        self.up_convolution_3 = UpSample(256, 128)
        self.up_convolution_4 = UpSample(128, 64)
        
        self.out = nn.Conv2d(in_channels=64, out_channels=num_classes, kernel_size=1)

    def forward(self, x):
       down_1, p1 = self.down_convolution_1(x)
       down_2, p2 = self.down_convolution_2(p1)
       down_3, p3 = self.down_convolution_3(p2)
       down_4, p4 = self.down_convolution_4(p3)

       b = self.bottle_neck(p4)

       up_1 = self.up_convolution_1(b, down_4)
       up_2 = self.up_convolution_2(up_1, down_3)
       up_3 = self.up_convolution_3(up_2, down_2)
       up_4 = self.up_convolution_4(up_3, down_1)

       out = self.out(up_4)
       return out

# class BarcodeDataset(Dataset):
#     def __init__(self, root_path, test=False):
#         self.root_path = root_path
#         if test:
#             self.images = sorted([root_path + "/predict/batch images/" + i for i in os.listdir(root_path + "/predict/batch images/")])
#             self.masks = sorted(
#                 [root_path + "/predict/batch masks/" + i for i in os.listdir(root_path + "/predict/batch masks/")])
#         else:
#             self.images = sorted([root_path + "/train/image/" + i for i in os.listdir(root_path + "/train/image/")])
#             self.masks = sorted([root_path + "/train/mask/" + i for i in os.listdir(root_path + "/train/mask/")])

#         self.transform = transforms.Compose([
#             transforms.Resize((448, 448)),
#             transforms.ToTensor()])

#     def __getitem__(self, index):
#         img = Image.open(self.images[index]).convert("RGB")
#         mask = Image.open(self.masks[index]).convert("L")

#         return self.transform(img), self.transform(mask)

#     def __len__(self):
#         return len(self.images)

# %%
def prediction(image_pth, model_pth, device):
    model = UNet(in_channels=3, num_classes=1).to(device)
    model.load_state_dict(torch.load(model_pth, map_location=torch.device(device)))

    transform = transforms.Compose([
        transforms.ToTensor()])

    img = transform(Image.open(image_pth)).float().to(device)
    img = img.unsqueeze(0)

    pred_mask = model(img)

    img = img.squeeze(0).cpu().detach()
    img = img.permute(1, 2, 0)

    pred_mask = pred_mask.squeeze(0).cpu().detach()
    pred_mask = pred_mask.permute(1, 2, 0)
    pred_mask[pred_mask < 0] = 0
    pred_mask[pred_mask > 0] = 1
    # plt.imshow(img,cmap="gray")
    return img, pred_mask

# %%
def find_contours(img):
    contours, _ = cv2.findContours(img, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    vertex_image = img.copy()
    contours_coordinates = []

    for contour in contours:
        epsilon = 0.018 * cv2.arcLength(contour, True)
        approx = cv2.approxPolyDP(contour, epsilon, True)

        for point in approx:
            x, y = point[0]
            contours_coordinates.append([y,x])
            cv2.circle(vertex_image, (x, y), 20, 128, -1)

    # plt.imshow(vertex_image, cmap='gray')

    return contours_coordinates

# %% [markdown]
# ## Measuring time

# %%
import time

number_of_images = 0
execution_time = []

# device = "cuda" if torch.cuda.is_available() else "cpu"
device = "cuda"
data_img_path = "/home/aous/Desktop/MIPT/project/full data resized/predict/input resized 2/"
output_img_path = "/home/aous/Desktop/MIPT/project/full data resized/predict/output predicted/"

for img in os.listdir(data_img_path):
    number_of_images += 1
    input_img_path= data_img_path+img
    input_image = cv2.imread(input_img_path,cv2.IMREAD_UNCHANGED)
    
    model_path = "/home/aous/Desktop/MIPT/project/models/model_full_data.pth"
    start_time = time.time()
    
    input_img, predicted_mask = prediction(input_img_path,model_path,device)
    predicted_mask = predicted_mask.squeeze()
    predicted_mask = predicted_mask.numpy().astype("uint8")
    
    # input_img = input_img.squeeze()
    # input_img = input_img.numpy().astype("uint8")
    # plt.imshow(input_img, cmap="gray")
    contours_of_pred_mask = find_contours(predicted_mask)
    end_time = time.time()
    time_ = end_time - start_time
    execution_time.append(time_)

# %%
average_execution_time = sum(execution_time) / number_of_images
print(f"average execution time is: {average_execution_time} seconds")
# Out:
# average execution time is: 0.2160076789855957 seconds

# %% [raw]
# 0.02:
# 0.289
# ============
# 0.013:
# 0.376
# ============
# 0.025:
# 0.3940
# ============
# 0.01:
# 0.501
# ============
# 0.015:
# 0.3075
# ============
# 0.018:
# 0.2776

# %% [markdown]
# ## Hausdorff metric distance

# %%
import pandas as pd

ground_truth = pd.read_csv('/home/aous/Desktop/MIPT/project/full data resized/predict/prediction.csv')
ground_truth['File Name'] = ground_truth['File Name'].str.rstrip('.json')
ground_truth = ground_truth.drop(["Value 1", "Value 2"], axis=1)
ground_truth.head()
# Out:
#   File Name  Value 3  Value 4  Value 5  Value 6  Value 7  Value 8  Value 9  \
# 0      1545      141       48       81       41       71      252      104
# 1      4735      329      198      305       93      173      152      186
# 2      2029      105       49       89      336      273      330      274
# 3      1361      288      196      278      196      277      247      283
# 4      6510      124      290      123      342      183      345      184
#
#    Value 10  Value 11  Value 12  Value 13  Value 14
# 0       249       102       314     133.0     315.0
# 1       202       120       230     135.0     282.0
# 2       244       434       238     438.0      65.0
# 3       245       284       273     290.0     271.0
# 4       328       212       327     212.0     292.0

# %%
import numpy as np
from scipy.spatial import distance_matrix

def Hausdorff_distance_metric(a, b):
    a = np.array(a)
    b = np.array(b)

    # Calculate the pairwise distances between vertices of both polygons
    distances_a = distance_matrix(a, b)
    distances_b = distance_matrix(b, a)

    # Find the maximum distance from each vertex in 'a' to the nearest vertex in 'b'
    if len(a) < 6:
        max_a_to_b = np.max(np.min(distances_a, axis=1))
        max_b_to_a = max_a_to_b 
    elif len(b) < 6:
    # Find the maximum distance from each vertex in 'b' to the nearest vertex in 'a'
        max_b_to_a = np.max(np.min(distances_b, axis=1))
        max_a_to_b = max_b_to_a
    else:
        max_a_to_b = np.max(np.min(distances_a, axis=1))
        max_b_to_a = np.max(np.min(distances_b, axis=1))

    # Calculate the Hausdorff distance 
    Hausdorff_distance = max(max_a_to_b, max_b_to_a)

    return Hausdorff_distance

# %%
predicted_dictionery = {
}

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

data_img_path = "/home/aous/Desktop/MIPT/project/full data resized/predict/input resized 2/"
output_img_path = "/home/aous/Desktop/MIPT/project/full data resized/predict/output predicted/"

for img in os.listdir(data_img_path):
    number_of_images += 1
    input_img_path= data_img_path+img
    input_image = cv2.imread(input_img_path,cv2.IMREAD_UNCHANGED)
    
    model_path = "/home/aous/Desktop/MIPT/project/models/model_full_data.pth"
    start_time = time.time()
    
    input_img, predicted_mask = prediction(input_img_path,model_path,device)
    predicted_mask = predicted_mask.squeeze()
    predicted_mask = predicted_mask.numpy().astype("uint8")
    
    input_img = input_img.squeeze()
    input_img = input_img.numpy().astype("uint8")
    # plt.imshow(input_img, cmap="gray")
    contours_of_pred_mask = find_contours(predicted_mask)
    img = img[:-4]
    predicted_dictionery[img] = contours_of_pred_mask

# %%
Hausdorff_distance_list = []
count  = 0
for i in predicted_dictionery:
    a = predicted_dictionery[f'{i}']
    filtered_df = ground_truth[ground_truth['File Name'] == f'{i}']
    values = filtered_df.iloc[:, 1:].values.flatten()
    b = []
    for j in range(0, len(values), 2):
    # Get the two consecutive elements in reverse order
        sublist = [values[j+1], values[j]]
        b.append(sublist)

    distance = Hausdorff_distance_metric(a,b)
    if len(a) <= 6:
        count += 1 
        Hausdorff_distance_list.append(distance)

# %%
average_Hausdorff_distance = sum(Hausdorff_distance_list) / count
print("Average Hausdorff distance is: ", average_Hausdorff_distance)
# Out:
# Average Hausdorff distance is:  7.95904582711214

# %% [markdown]
# ## Accuracy and IoU

# %%
def calculate_iou(predicted_probs, binary_mask):
    # predicted_mask = (predicted_probs >= 0.5).float()
    # intersection = torch.logical_and(predicted_mask, binary_mask).sum()
    # print(intersection)
    # union = torch.logical_or(predicted_mask, binary_mask).sum()
    # print(union)
    # iou = intersection.float() / union.float()
    predicted_mask = predicted_probs
    true_positives = torch.logical_and(predicted_mask, binary_mask).sum()
    false_positives = torch.logical_and(torch.logical_not(predicted_mask), binary_mask).sum()
    false_negatives = torch.logical_and(predicted_mask, torch.logical_not(binary_mask)).sum()

    iou = true_positives / (true_positives + false_positives + false_negatives)
    # iou *= 100
    return iou.item()

def calculate_accuracy(predicted_probs, binary_mask):
    predicted_mask = (predicted_probs >= 0.5).float()

    true_positives = torch.logical_and(predicted_mask, binary_mask).sum()
    true_negatives = torch.logical_not(torch.logical_or(predicted_mask, binary_mask)).sum()
    false_positives = torch.logical_and(torch.logical_not(predicted_mask), binary_mask).sum()
    false_negatives = torch.logical_and(predicted_mask, torch.logical_not(binary_mask)).sum()
    accuracy = (true_positives + true_negatives) / (true_positives + true_negatives + false_positives + false_negatives)
    precision = (true_positives) / (true_positives + false_positives)

    # accuracy = (predicted_mask == binary_mask).float().mean().item()
    return  accuracy.item()        #   accuracy.item()

# %%
import torch
import os
import cv2

device = "cuda" if torch.cuda.is_available() else "cpu"
accuracy_list = []
iou_list = []
number_of_images = 0
data_img_path = "/home/aous/Desktop/MIPT/project/full data resized/predict/input resized 2/"
masks_path = "/home/aous/Desktop/MIPT/project/full data resized/predict/mask resized/"

for img in os.listdir(data_img_path):
   # print(mask_tensor)
        number_of_images += 1
        input_img_path= data_img_path + img
        mask_path = masks_path + img
        
        mask = cv2.imread(mask_path, cv2.IMREAD_UNCHANGED)
        
        mask_tensor = torch.tensor(mask)
        mask_tensor = mask_tensor / 255
 
        input_img, predicted_mask = prediction(input_img_path,model_path,device)
        predicted_mask = predicted_mask.squeeze()
        mask_tensor = mask_tensor.squeeze()
        iou = calculate_iou(predicted_mask, mask_tensor)
        acc = calculate_accuracy(predicted_mask, mask_tensor)
        iou_list.append(iou)
        accuracy_list.append(acc)


    # number_of_images += 1
    # input_img_path= data_img_path + img
    # mask_path = masks_path + img
    # input_image = cv2.imread(input_img_path,cv2.IMREAD_UNCHANGED)
    # mask = cv2.imread(mask_path, cv2.IMREAD_UNCHANGED)
    # mask_tensor = torch.tensor(mask)
    # model_path = "/home/aous/Desktop/MIPT/project/models/model_full_data.pth"
    
    # input_img, predicted_mask = prediction(input_img_path,model_path,device)
    # accuracy = calculate_accuracy(predicted_mask, mask_tensor)
    # iou = calculate_iou(predicted_mask, mask_tensor)
    # accuracy_list.append(accuracy)
    # iou_list.append(iou)


    
    # predicted_mask = predicted_mask.squeeze()
    # predicted_mask = predicted_mask.numpy().astype("uint8")
    
    # input_img = input_img.squeeze()
    # input_img = input_img.numpy().astype("uint8")
    # plt.imshow(input_img, cmap="gray")
iou_list, accuracy_list
# Out:
# ([0.9650887250900269,
#   0.7343083620071411,
#   0.9534901976585388,
#   0.7438570261001587,
#   0.9087560772895813,
#   0.955559492111206,
#   0.9464020133018494,
#   0.9755975008010864,
#   0.8362111449241638,
#   0.8867112994194031,
#   0.856176495552063,
#   0.9293918013572693,
#   0.9375987648963928,
#   0.8508039712905884,
#   0.9442607760429382,
#   0.7035230398178101,
#   0.9198544025421143,
#   0.8966578841209412,
#   0.96454918384552,
#   0.9427809715270996,
#   0.913783073425293,
#   0.9618013501167297,
#   0.9143723845481873,
#   0.9513101577758789,
#   0.8563812971115112,
#   0.9321264028549194,
#   0.8205912113189697,
#   0.8724308013916016,
#   0.9437099695205688,
#   0.9184210300445557,
#   0.9512694478034973,
#   0.8869704604148865,
#   0.8585978150367737,
#   0.8338778614997864,
#   0.9625831246376038,
#   0.9670392870903015,
#   0.9328086972236633,
#   0.9476616382598877,
#   0.9608079791069031,
#   0.937870442867279,
#   0.9568013548851013,
# ...

# %%
avg_iou = sum(iou_list) / number_of_images
avg_acc = sum(accuracy_list) / number_of_images

print(f"The average IoU is: {avg_iou * 100} %")
print(f"The average Accuracy is: {avg_acc * 100} %")
# Out:
# The average IoU is: 92.13450217247009 %
# The average Accuracy is: 99.58241577148438 %

# %% [markdown]
# ## tt

# %%
import matplotlib.pyplot as plt

vertices = [[141, 48], [81, 41], [71, 252], [104, 249], [102, 314], [133, 315]]

# Extract x and y coordinates from the vertices
x_coordinates = [vertex[0] for vertex in vertices]
y_coordinates = [vertex[1] for vertex in vertices]

# Create a figure and axis with a range of 512 for both x and y
fig, ax = plt.subplots(figsize=(6, 6))
ax.set_xlim(0, 512)
ax.set_ylim(0, 512)

# Plot the points
ax.plot(x_coordinates, y_coordinates, 'ro')

# # Add labels to the points
# for i, vertex in enumerate(vertices):
#     ax.annotate(f'({vertex[0]}, {vertex[1]})', (vertex[0], vertex[1]), textcoords="offset points", xytext=(0,10), ha='center')

# Show the plot
plt.show()

# %%
how can i save the lines equations which represents the ribs of the polygon

import matplotlib.pyplot as plt

vertices = [[141, 48], [81, 41], [71, 252], [104, 249], [102, 314], [133, 315],[141,48]]

# Extract x and y coordinates from the vertices
x_coordinates, y_coordinates = zip(*vertices)

# Create a figure and axis with a range of 512 for both x and y
fig, ax = plt.subplots(figsize=(6, 6))
ax.set_xlim(0, 512)
ax.set_ylim(0, 512)

# Plot the vertices
ax.plot(x_coordinates, y_coordinates, 'bo-')


# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

vertices = [[141, 48], [81, 41], [71, 252], [104, 249], [102, 314], [133, 315],[141,48]]

# Extract x and y coordinates from the vertices
x_coordinates, y_coordinates = zip(*vertices)

# Create a figure and axis with a range of 512 for both x and y
fig, ax = plt.subplots(figsize=(6, 6))
ax.set_xlim(0, 512)
ax.set_ylim(0, 512)

# Plot the vertices
ax.plot(x_coordinates, y_coordinates, 'bo-')


# Show the plot
plt.show()

# %%
edit this code where if the intersection point belongs to the polygon, do not add it to the intersection_points, also if x>=512 or y>=512 dont add it

import matplotlib.pyplot as plt
from shapely.geometry import LineString

vertices = [[141, 48], [81, 41], [71, 252], [104, 249], [102, 314], [133, 315], [141, 48]]

# Extract x and y coordinates from the vertices
x_coordinates, y_coordinates = zip(*vertices)

# Create a figure and axis with a range of 512 for both x and y
fig, ax = plt.subplots(figsize=(6, 6))
ax.set_xlim(0, 512)
ax.set_ylim(0, 512)

# Plot the vertices
ax.plot(x_coordinates, y_coordinates, 'bo-')

# Save the line equations
line_equations = []
for i in range(len(vertices) - 1):
    x1, y1 = vertices[i]
    x2, y2 = vertices[i + 1]
    slope = (y2 - y1) / (x2 - x1)
    intercept = y1 - slope * x1
    line_equations.append((slope, intercept))

# Calculate and plot the intersection points
intersection_points = []
for i in range(len(line_equations) - 1):
    for j in range(i + 1, len(line_equations)):
        slope1, intercept1 = line_equations[i]
        slope2, intercept2 = line_equations[j]
        x = (intercept2 - intercept1) / (slope1 - slope2)
        y = slope1 * x + intercept1
        intersection_points.append((x, y))
        ax.plot(x, y, 'bo')


plt.show()
intersection_points
# Out:
# [(81.0, 41.0),
#  (1093.1167883211676, 159.0802919708029),
#  (110.29483903934593, 44.41773122125703),
#  (3307.24203821656, 417.3949044585987),
#  (141.0, 48.0),
#  (71.0, 252.0),
#  (164.81578947368422, -1727.5131578947373),
#  (68.11341779880935, 312.90688444512284),
#  (244.70672097759675, -3413.2118126272917),
#  (104.0, 248.99999999999997),
#  (-424.2619047619047, 297.0238095238095),
#  (135.0621372482076, 246.176169341072),
#  (102.00000000000001, 313.99999999999955),
#  (1285.5714285714287, -38152.071428571435),
#  (133.0, 315.0)]

# %%
import matplotlib.pyplot as plt
from shapely.geometry import LineString
from math import sqrt

vertices = [[141, 48], [81, 41], [71, 252], [104, 249], [102, 314], [133, 315], [141, 48]]

# External point not on the polygon
external_point = [200, 200]

# Extract x and y coordinates from the vertices
x_coordinates, y_coordinates = zip(*vertices)

# Create a figure and axis with a range of 512 for both x and y
fig, ax = plt.subplots(figsize=(6, 6))
ax.set_xlim(0, 512)
ax.set_ylim(0, 512)

# Plot the vertices
ax.plot(x_coordinates, y_coordinates, 'bo-')

# Save the line equations
line_equations = []
for i in range(len(vertices) - 1):
    x1, y1 = vertices[i]
    x2, y2 = vertices[i + 1]
    slope = (y2 - y1) / (x2 - x1)
    intercept = y1 - slope * x1
    line_equations.append((slope, intercept))

# Calculate the intersection points and distances
intersection_points = []
distances = []
for i in range(len(line_equations) - 1):
    for j in range(i + 1, len(line_equations)):
        slope1, intercept1 = line_equations[i]
        slope2, intercept2 = line_equations[j]
        x = (intercept2 - intercept1) / (slope1 - slope2)
        y = slope1 * x + intercept1
        if x <= 512 and y <= 512:
            intersection_points.append((x, y))
        # distance = sqrt((x - external_point[0]) ** 2 + (y - external_point[1]) ** 2)
        # distances.append(distance)
print(intersection_points)
# Find the index of the intersection point with the maximum distance
# max_distance_index = distances.index(max(distances))

# Plot the intersection point with the maximum distance
# max_distance_intersection = intersection_points[max_distance_index]
ax.plot(max_distance_intersection[0], max_distance_intersection[1], 'ro')

# Print the line equations
for i, equation in enumerate(line_equations):
    slope, intercept = equation
    print(f"Line {i + 1}: y = {slope}x + {intercept}")
print(max_distance_intersection)
# Show the plot
plt.show()
# Out:
# [(81.0, 41.0), (110.29483903934593, 44.41773122125703), (141.0, 48.0), (71.0, 252.0), (164.81578947368422, -1727.5131578947373), (68.11341779880935, 312.90688444512284), (244.70672097759675, -3413.2118126272917), (104.0, 248.99999999999997), (-424.2619047619047, 297.0238095238095), (135.0621372482076, 246.176169341072), (102.00000000000001, 313.99999999999955), (133.0, 315.0)]
# Line 1: y = 0.11666666666666667x + 31.55
# Line 2: y = -21.1x + 1750.1000000000001
# Line 3: y = -0.09090909090909091x + 258.45454545454544
# Line 4: y = -32.5x + 3629.0
# Line 5: y = 0.03225806451612903x + 310.7096774193548
# Line 6: y = -33.375x + 4753.875
# (1285.5714285714287, -38152.071428571435)

# %%
import matplotlib.pyplot as plt
from shapely.geometry import LineString

vertices = [[141, 48], [81, 41], [71, 252], [104, 249], [102, 314], [133, 315], [141, 48]]

# Extract x and y coordinates from the vertices
x_coordinates, y_coordinates = zip(*vertices)

# Create a figure and axis with a range of 512 for both x and y
fig, ax = plt.subplots(figsize=(6, 6))
ax.set_xlim(0, 512)
ax.set_ylim(0, 512)

# Plot the vertices
# ax.plot(x_coordinates, y_coordinates, 'bo-')

# Save the line equations
line_equations = []
for i in range(len(vertices) - 1):
    x1, y1 = vertices[i]
    x2, y2 = vertices[i + 1]
    slope = (y2 - y1) / (x2 - x1)
    intercept = y1 - slope * x1
    line_equations.append((slope, intercept))

# Calculate and plot the intersection points
intersection_points = []
for i in range(len(line_equations) - 1):
    for j in range(i + 1, len(line_equations)):
        slope1, intercept1 = line_equations[i]
        slope2, intercept2 = line_equations[j]
        x = (intercept2 - intercept1) / (slope1 - slope2)
        y = slope1 * x + intercept1
        
        # Check if the intersection point is within the polygon
        if LineString(vertices).contains(Point(x, y)):
            continue
        
        # Check if x or y is greater than or equal to 512
        if x >= 512 or y >= 512:
            continue
        
        intersection_points.append((x, y))
        ax.plot(x, y, 'bo')

plt.show()
intersection_points
# Out:
# [(110.29483903934593, 44.41773122125703),
#  (164.81578947368422, -1727.5131578947373),
#  (68.11341779880935, 312.90688444512284),
#  (244.70672097759675, -3413.2118126272917),
#  (104.0, 248.99999999999997),
#  (-424.2619047619047, 297.0238095238095),
#  (135.0621372482076, 246.176169341072),
#  (102.00000000000001, 313.99999999999955)]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
img = plt.imread("/home/aous/Desktop/MIPT/project/DATASET/train/input/1.jpg")
plt.imshow(img, cmap='gray')
plt.show()

# %%
plt.figure(figsize=(10,8))
mask = cv2.imread("/home/aous/Desktop/MIPT/project/DATASET/train/mask/1m.PNG",0)
plt.imshow(mask, cmap='gray')
plt.show()

# %%
import cv2
import numpy as np

contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
vertex_image = mask.copy()
contours_coordinates = []


for contour in contours:
    epsilon = 0.03 * cv2.arcLength(contour, True)
    approx = cv2.approxPolyDP(contour, epsilon, True)

    for point in approx:
        x, y = point[0]
        contours_coordinates.append([y,x])
        cv2.circle(vertex_image, (x, y), 25, 128, -1)
plt.figure(figsize=(10,8))
# for point in contours:
#     cv2.circle(vertex_image, (point[0], point[1]), 15, 128, -1)
plt.imshow(vertex_image, cmap="gray")

# print(contours_coordinates)
